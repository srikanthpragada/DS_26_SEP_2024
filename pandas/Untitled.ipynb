# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('marks.csv',header=None, names=['name','subject','marks'])

# %%
df
# Out:
#       name subject  marks
# 0     Bill    Java   90.0
# 1     Bill  Python   95.0
# 2    Steve    Java   80.0
# 3    Steve       C   90.0
# 4  Roberts    HTML   98.0
# 5  Roberts    Java   60.0
# 6  Roberts  Python   70.0
# 7    Steve  Python    NaN
# 8    Henry     NaN   60.0
# 9    Steve  Python   94.0

# %%
df['result'] = df.marks > 60

# %%
df
# Out:
#       name subject  marks  result
# 0     Bill    Java   90.0    True
# 1     Bill  Python   95.0    True
# 2    Steve    Java   80.0    True
# 3    Steve       C   90.0    True
# 4  Roberts    HTML   98.0    True
# 5  Roberts    Java   60.0   False
# 6  Roberts  Python   70.0    True
# 7    Steve  Python    NaN   False
# 8    Henry     NaN   60.0   False
# 9    Steve  Python   94.0    True

# %%
df2 = df[:]

# %%
df2
# Out:
#       name subject  marks  result
# 0     Bill    Java   90.0    True
# 1     Bill  Python   95.0    True
# 2    Steve    Java   80.0    True
# 3    Steve       C   90.0    True
# 4  Roberts    HTML   98.0    True
# 5  Roberts    Java   60.0   False
# 6  Roberts  Python   70.0    True
# 7    Steve  Python    NaN   False
# 8    Henry     NaN   60.0   False
# 9    Steve  Python   94.0    True

# %%
id(df2), id(df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 id(df2), id(df1)
#
# NameError: name 'df1' is not defined
