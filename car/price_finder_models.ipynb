# %%
# import pandas library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ## Build model using LinearRegression

# %%
cars = pd.read_csv("cars.csv")

# %%
cars.columns
# Out:
# Index(['make', 'fuel-type', 'num-of-doors', 'body-style', 'drive-wheels',
#        'curb-weight', 'engine-size', 'highway-mpg', 'wheel-base', 'price'],
#       dtype='object')

# %%
## create X and Y
y = cars['price']
X = cars.drop(columns=['price'])

# %%
X.sample(5)
# Out:
#            make fuel-type num-of-doors body-style drive-wheels  curb-weight  \
# 73   mitsubishi       gas          two  hatchback          fwd         1918
# 192       volvo       gas         four      sedan          rwd         2935
# 104      peugot       gas         four      sedan          rwd         3020
# 43        isuzu       gas          two  hatchback          rwd         2734
# 46       jaguar       gas          two      sedan          rwd         3950
#
#      engine-size  highway-mpg  wheel-base
# 73            92           41        93.7
# 192          141           28       104.3
# 104          120           24       107.9
# 43           119           29        96.0
# 46           326           17       102.0

# %%
X  = pd.get_dummies(X)

# %%
X.shape,y.shape
# Out:
# ((201, 39), (201,))

# %%
X.columns
# Out:
# Index(['curb-weight', 'engine-size', 'highway-mpg', 'wheel-base',
#        'make_alfa-romero', 'make_audi', 'make_bmw', 'make_chevrolet',
#        'make_dodge', 'make_honda', 'make_isuzu', 'make_jaguar', 'make_mazda',
#        'make_mercedes-benz', 'make_mercury', 'make_mitsubishi', 'make_nissan',
#        'make_peugot', 'make_plymouth', 'make_porsche', 'make_renault',
#        'make_saab', 'make_subaru', 'make_toyota', 'make_volkswagen',
#        'make_volvo', 'fuel-type_diesel', 'fuel-type_gas', 'num-of-doors_?',
#        'num-of-doors_four', 'num-of-doors_two', 'body-style_convertible',
#        'body-style_hardtop', 'body-style_hatchback', 'body-style_sedan',
#        'body-style_wagon', 'drive-wheels_4wd', 'drive-wheels_fwd',
#        'drive-wheels_rwd'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=99)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Display coefficient for each column
for t in zip(X_train.columns, model.coef_):
    print(f"{t[0]:25s} {t[1]:.0f}")
# Out:
# curb-weight               6
# engine-size               34
# highway-mpg               -55
# wheel-base                67
# make_alfa-romero          -1921
# make_audi                 2571
# make_bmw                  7784
# make_chevrolet            -44
# make_dodge                -1989
# make_honda                -1091
# make_isuzu                -5830
# make_jaguar               5869
# make_mazda                -1143
# make_mercedes-benz        6363
# make_mercury              -1360
# make_mitsubishi           -2767
# make_nissan               -1654
# make_peugot               -3988
# make_plymouth             -2604
# make_porsche              12177
# make_renault              -3024
# make_saab                 -301
# make_subaru               -2260
# make_toyota               -2923
# make_volkswagen           -1441
# make_volvo                -422
# fuel-type_diesel          -38
# fuel-type_gas             38
# num-of-doors_?            62
# num-of-doors_four         -36
# num-of-doors_two          -26
# body-style_convertible    3169
# body-style_hardtop        -1128
# body-style_hatchback      -142
# body-style_sedan          -158
# body-style_wagon          -1741
# drive-wheels_4wd          -414
# drive-wheels_fwd          -307
# drive-wheels_rwd          721

# %%
model.intercept_
# Out:
# -10323.353974579677

# %% [markdown]
# ### Calculate accuracy with train data

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
y_pred = model.predict(X_train)
mse = mean_squared_error(y_train,y_pred)
print("MSE  : ", mse )
print("RMSE : ", np.sqrt(mse))
# Out:
# MSE  :  3894987.049060841
# RMSE :  1973.5721545109116

# %%
r2score = r2_score(y_train,y_pred)
print(f"R2 Score: {r2score:0.2f}")
# Out:
# R2 Score: 0.93

# %% [markdown]
# ### Test with test data

# %%
y_pred = model.predict(X_test)

# %%
## get MSE 
mse = mean_squared_error(y_test,y_pred)
print(f"Mean Squared Error : {mse:0.2f}")

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error : {rmse:0.2f}")

r2score = r2_score(y_test,y_pred)
print(f"R2 Score: {r2score:0.2f}")
# Out:
# Mean Squared Error : 6426967.32
# Root Mean Squared Error : 2535.15
# R2 Score: 0.93

# %%
# Compare actual and predicted values
plt.gcf().set_size_inches(20,10)
sns.lineplot( y = y_test, x = X_test.index, label="Actual")
sns.lineplot( y = y_pred, x = X_test.index, label="Predicted")
# Out:
# <Axes: ylabel='price'>

# %%
# Display % of difference 
for p,a in zip(y_pred[:10],y_test[:10]):
    d = p - a
    print(f"{p:6.0f}  -  {a:6.0f} - {p - a:6.0f} - {abs(d / a * 100):5.2f}")
# Out:
#  34674  -   45400 - -10726 - 23.63
#   6287  -    6692 -   -405 -  6.05
#   6896  -    7395 -   -499 -  6.75
#  16404  -   16558 -   -154 -  0.93
#   9954  -    9549 -    405 -  4.25
#  11422  -   12945 -  -1523 - 11.77
#  29048  -   34028 -  -4980 - 14.64
#   9256  -    9279 -    -23 -  0.25
#   7380  -    7463 -    -83 -  1.11
#  14498  -   15510 -  -1012 -  6.52

# %% [markdown]
# ## Model with Standardization

# %%
cars = pd.read_csv("old_cars.csv")

# %%
## create X and Y
y = cars['price']
X = cars.drop(columns=['price'])

# %%
X = pd.get_dummies(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=99)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
## Scale X_train and X_test
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_data = pd.DataFrame(X_train_scaled,columns = X.columns)

# %%
X_test_data = pd.DataFrame(X_test_scaled,columns = X.columns)

# %%
X_test_data.head()
# Out:
#    curb-weight  engine-size  highway-mpg  wheel-base  make_alfa-romero  \
# 0     2.413275     4.982797    -2.238975    2.243682         -0.138233
# 1    -1.071322    -0.923353     1.017716   -0.806509         -0.138233
# 2    -1.150058    -0.895755     1.017716   -0.906515         -0.138233
# 3     0.921319     1.312152    -1.054724    0.726920         -0.138233
# 4    -0.439410    -0.095388     0.425590   -0.223139         -0.138233
#
#    make_audi  make_bmw  make_chevrolet  make_dodge  make_honda  ...  \
# 0  -0.197386 -0.197386       -0.138233   -0.229416   -0.271708  ...
# 1  -0.197386 -0.197386       -0.138233    4.358899   -0.271708  ...
# 2  -0.197386 -0.197386       -0.138233   -0.229416   -0.271708  ...
# 3  -0.197386 -0.197386       -0.138233   -0.229416   -0.271708  ...
# 4  -0.197386 -0.197386       -0.138233   -0.229416   -0.271708  ...
#
#    num-of-doors_four  num-of-doors_two  body-style_convertible  \
# 0          -1.119608          1.148408               -0.197386
# 1           0.893170         -0.870771               -0.197386
# 2           0.893170         -0.870771               -0.197386
# 3          -1.119608          1.148408               -0.197386
# 4           0.893170         -0.870771               -0.197386
#
#    body-style_hardtop  body-style_hatchback  body-style_sedan  \
# 0            5.567764             -0.733799         -0.916013
# 1           -0.179605             -0.733799          1.091687
# 2           -0.179605             -0.733799          1.091687
# 3           -0.179605              1.362770         -0.916013
# 4           -0.179605             -0.733799          1.091687
#
#    body-style_wagon  drive-wheels_4wd  drive-wheels_fwd  drive-wheels_rwd
# 0         -0.377964         -0.229416         -1.224745          1.362770
# 1         -0.377964         -0.229416          0.816497         -0.733799
# 2         -0.377964         -0.229416          0.816497         -0.733799
# 3         -0.377964         -0.229416         -1.224745          1.362770
# 4         -0.377964         -0.229416          0.816497         -0.733799
#
# [5 rows x 39 columns]

# %%
model = LinearRegression()
model.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
## get MSE 
mse = mean_squared_error(y_test,y_pred)
print(f"Mean Squared Error : {mse:0.2f}")

rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print(f"Root Mean Squared Error : {rmse:0.2f}")

mae = mean_absolute_error(y_test,y_pred)
print(f"Mean Absolute Error : {mae:0.2f}")

r2score = r2_score(y_test,y_pred)
print(f"R2 Score: {r2score:0.2f}")
# Out:
# Mean Squared Error : 6410602.71
# Root Mean Squared Error : 2531.92
# Mean Absolute Error : 1638.99
# R2 Score: 0.93

# %% [markdown]
# ### Micro model with 2 features

# %%
# Micro model
X_micro =  X[['engine-size','highway-mpg']]
y_micro =  y

# %%
X_micro_train, X_micro_test, y_micro_train, y_micro_test = train_test_split(X_micro,y_micro, test_size=0.2, random_state=0)

# %%
micro_model = LinearRegression()
micro_model.fit(X_micro_train,y_micro_train)
# Out:
# LinearRegression()

# %%
micro_model.score(X_micro_train,y_micro_train) # r2 for train data
# Out:
# 0.7796926906820936

# %%
y_micro_pred = micro_model.predict(X_micro_test)

# %%
r2score = r2_score(y_micro_test,y_micro_pred)
print(f"R2 Score: {r2score:0.2f}")

mse = mean_squared_error(y_micro_test,y_micro_pred)
print(f"Mean Squared Error : {mse:0.2f}")

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error : {rmse:0.2f}")
# Out:
# R2 Score: 0.79
# Mean Squared Error : 15885068.97
# Root Mean Squared Error : 3985.61

# %% [markdown]
# ## RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=99)

# %%
model = RandomForestRegressor(n_estimators=10)
model.fit(X_train, y_train)
print(f'Train score : {model.score(X_train,y_train)}')
# Out:
# Train score : 0.9809747973303787

# %%
y_pred = model.predict(X_test)
r2score = r2_score(y_test,y_pred)
print(f'Test Score  : {r2score:0.2f}')
# Out:
# Test Score  : 0.93

# %%
mse = mean_squared_error(y_test,y_pred)
print("MSE  : ",mse)
print("RMSE : ", np.sqrt(mse))
# Out:
# MSE  :  6474476.648960026
# RMSE :  2544.4992923874092

# %%
for f,v in sorted(zip (X_train.columns, model.feature_importances_),key = lambda t : t[1], reverse = True):
      print(f"{f:30} {v:0.5f}")
# Out:
# engine-size                    0.51329
# curb-weight                    0.37668
# highway-mpg                    0.04132
# make_bmw                       0.02054
# wheel-base                     0.01310
# make_porsche                   0.00402
# drive-wheels_fwd               0.00368
# fuel-type_gas                  0.00336
# body-style_sedan               0.00317
# body-style_convertible         0.00219
# drive-wheels_rwd               0.00197
# make_volvo                     0.00196
# body-style_wagon               0.00178
# make_audi                      0.00158
# body-style_hatchback           0.00143
# make_peugot                    0.00134
# make_mercedes-benz             0.00128
# make_subaru                    0.00121
# body-style_hardtop             0.00109
# make_toyota                    0.00107
# num-of-doors_four              0.00088
# num-of-doors_two               0.00058
# make_plymouth                  0.00050
# make_alfa-romero               0.00040
# make_isuzu                     0.00039
# make_dodge                     0.00027
# fuel-type_diesel               0.00024
# make_volkswagen                0.00018
# drive-wheels_4wd               0.00015
# make_honda                     0.00014
# make_nissan                    0.00010
# make_mitsubishi                0.00004
# make_saab                      0.00003
# num-of-doors_?                 0.00001
# make_mazda                     0.00000
# make_jaguar                    0.00000
# make_chevrolet                 0.00000
# make_renault                   0.00000
# make_mercury                   0.00000

# %%
# Compare actual and predicted values
plt.gcf().set_size_inches(20,10)
sns.lineplot( y = y_test, x = X_test.index, label="Actual")
sns.lineplot( y = y_pred, x = X_test.index, label="Predicted")
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# ### SGDRegressor

# %%
from sklearn.linear_model import SGDRegressor

# %%
X_mini = X[['curb-weight','engine-size','highway-mpg']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
## use same scale for X_train and X_test
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = SGDRegressor(max_iter=100)
model.fit(X_train, y_train)
print(f'Train score : {model.score(X_train,y_train)}')
print('No. of iterations = ', model.n_iter_)
# Out:
# Train score : 0.935091766473469
# No. of iterations =  27

# %%
y_pred = model.predict(X_test)
r2score = r2_score(y_test,y_pred)
print(f'Test Score  : {r2score:0.2f}')
# Out:
# Test Score  : 0.90

# %%
mse = mean_squared_error(y_test,y_pred)
print("MSE  : ",mse)
print("RMSE : ", np.sqrt(mse))
# Out:
# MSE  :  6149841.2127641635
# RMSE :  2479.887338724113
